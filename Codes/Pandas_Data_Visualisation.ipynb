# %% [markdown]
# **Loading the external dependencies**

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# **Generating data**

# %%
date = np.array('2001-01-01', dtype=np.datetime64)
date = date + np.arange(1000)
df1 = pd.DataFrame(np.random.randn(1000,4), index=date, columns='a b c d'.split())

# %%
df1.head()
# Out:
#                    a         b         c         d
# 2001-01-01  0.125925  0.134552 -0.252861 -1.395165
# 2001-01-02 -0.438273 -1.307960 -0.925281  0.626653
# 2001-01-03  0.151650 -0.772603  0.265752  0.533095
# 2001-01-04 -1.812757 -0.504872 -1.210523  0.344678
# 2001-01-05  0.005520 -0.107869 -0.621913 -0.019792

# %%
df2 = pd.DataFrame(np.random.random((10,4)),columns='a b c d'.split())
df2.head()
# Out:
#           a         b         c         d
# 0  0.407688  0.713410  0.434402  0.656972
# 1  0.437407  0.842722  0.566319  0.345079
# 2  0.610282  0.053279  0.830386  0.256470
# 3  0.733889  0.790590  0.791241  0.194576
# 4  0.933770  0.486900  0.944820  0.343229

# %% [markdown]
# **Histogram**

# %%
df1['a'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df1['a'].plot.hist(bins=50, edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.style.use('dark_background')
df1['a'].plot.hist(bins=20, edgecolor='white')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.style.use('ggplot')

# %% [markdown]
# **Area plot**

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Bar plot**

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Line plot**

# %%
df1.plot.line(y='b',figsize=(12,3),lw=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Scatter plot**

# %%
df1.plot.scatter(x='c',y='d')
# Out:
# <AxesSubplot:xlabel='c', ylabel='d'>

# %%
df1.plot.scatter(x='a',y='b',c='c',cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# **Box plot**

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Hexagonal bin plot**

# %%
df = pd.DataFrame(np.random.randn(500, 2), columns=['A', 'B'])
df.plot.hexbin(x='A',y='B',gridsize=20,cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# **Kde plot**

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
